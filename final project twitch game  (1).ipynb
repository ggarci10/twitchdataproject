# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ggarci10/refactored-meme/main/Twitch_game_data%202016-2019.csv")

# %%
df
# Out:
#       Rank                              Game  Month  Year  Hours_watched  \
# 0        1                 League of Legends      1  2016       94377226
# 1        2  Counter-Strike: Global Offensive      1  2016       47832863
# 2        3                            Dota 2      1  2016       45185893
# 3        4                       Hearthstone      1  2016       39936159
# 4        5       Call of Duty: Black Ops III      1  2016       16153057
# ...    ...                               ...    ...   ...            ...
# 9595   196                     Hollow Knight     12  2019         282292
# 9596   197         Kingdom Come: Deliverance     12  2019         277506
# 9597   198   Barbie and The Magic of Pegasus     12  2019         276731
# 9598   199                         StarCraft     12  2019         275977
# 9599   200                 Final Fantasy VII     12  2019         275048
#
#       Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df['Year']
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 9595    2019
# 9596    2019
# 9597    2019
# 9598    2019
# 9599    2019
# Name: Year, Length: 9600, dtype: int64

# %%
df['Hours_watched']
# Out:
# 0       94377226
# 1       47832863
# 2       45185893
# 3       39936159
# 4       16153057
#           ...
# 9595      282292
# 9596      277506
# 9597      276731
# 9598      275977
# 9599      275048
# Name: Hours_watched, Length: 9600, dtype: int64

# %%
mask2016 = df['Year'] == 2016
 
df_2016 = pd.DataFrame(df[mask2016])
 
# print(df_new)

grouped = df_2016.groupby("Game")
# sum and average the other information by game
result = grouped.agg({"Hours_streamed": "sum", "Peak_viewers": "max", "Peak_channels": "max", "Avg_viewers": "mean", "Avg_channels": "mean", "Avg_viewer_ratio": "mean"})
print(result)
# Out:
#                                  Hours_streamed  Peak_viewers  Peak_channels  \
# Game
# 60 Seconds!                                3165         56904             30
# 7 Days to Die                            649580         36862            950
# ABZ<U+00DB>                                5738         28205            116
# APB Reloaded                              10747         17386             37
# ARAYA                                       437         28289             12
# ...                                         ...           ...            ...
# Z1: Battle Royale                       2172785         84161            882
# Zelda II: The Adventure of Link             747         94715             12
# Zero Escape: Zero Time Dilemma             3755         17601             27
# iRacing                                   30107          1548             61
# osu!                                     783320         37612            192
#
# ...

# %%
mask2017 = df['Year'] == 2017
 
df_2017 = pd.DataFrame(df[mask2017])
 
# print(df_new)

grouped = df_2017.groupby("Game")
# sum and average the other information by game
result = grouped.agg({"Hours_streamed": "sum", "Peak_viewers": "max", "Peak_channels": "max", "Avg_viewers": "mean", "Avg_channels": "mean", "Avg_viewer_ratio": "mean"})
print(result)
# Out:
#                              Hours_streamed  Peak_viewers  Peak_channels  \
# Game
# .hack//G.U. Last Recode               35258          1222            258
# 60 Seconds!                            1932         31311             10
# 7 Days to Die                        726805         39478            266
# <U+014C>kami                          19273         29429            148
# A Hat in Time                         26921         28625            182
# ...                                     ...           ...            ...
# Yu-Gi-Oh! Duel Links                  56977         22914             52
# Z1: Battle Royale                   3492949        145097           1184
# iRacing                               11507          1638            131
# osu!                                 895477         18701            237
# theHunter: Call of the Wild           60069         46646             71
#
#                               Avg_viewers  Avg_channels  Avg_viewer_ratio
# Game
# ...

# %%
mask2018 = df['Year'] == 2018
 
df_2018 = pd.DataFrame(df[mask2018])
 
# print(df_new)

grouped = df_2018.groupby("Game")
# sum and average the other information by game
result = grouped.agg({"Hours_streamed": "sum", "Peak_viewers": "max", "Peak_channels": "max", "Avg_viewers": "mean", "Avg_channels": "mean", "Avg_viewer_ratio": "mean"})
print(result)
# Out:
#                                                    Hours_streamed  \
# Game
# 60 Parsecs!                                                  1867
# 60 Seconds!                                                   871
# 7 Days to Die                                              645756
# A Hat in Time                                               14520
# A Way Out                                                  138910
# ...                                                           ...
# Z1: Battle Royale                                          802567
# Zero Escape: Nine Hours, Nine Persons, Nine Doors             661
# iRacing                                                    109246
# osu!                                                      1373645
# theHunter: Call of the Wild                                  8633
#
#                                                    Peak_viewers  \
# Game
# 60 Parsecs!                                               31960
# ...
