# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ggarci10/refactored-meme/main/Twitch_game_data%202016-2019.csv")
df.head()
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
#
#    Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0         1362044        530270           2903     129172       127021
# 1          830105        372654           2197     120849        64378
# 2          433397        315083           1100      44074        60815
# 3          235903        131357            517      36170        53749
# 4         1151578         71639           3620     214054        21740
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
# 3           317            169.29
# 4          1549             14.03

# %%
goty = pd.read_csv("https://raw.githubusercontent.com/ggarci10/refactored-meme/main/the_game_awards.csv")

# %%
goty_2016 = goty[goty['year'] == 2016]
goty_2017 = goty[goty['year'] == 2017]
goty_2018 = goty[goty['year'] == 2018]
print(goty_2016.head())
# Out:
#      year          category                     nominee  \
# 215  2016  Game of the Year                   Overwatch
# 216  2016  Game of the Year                        Doom
# 217  2016  Game of the Year                      Inside
# 218  2016  Game of the Year                 Titanfall 2
# 219  2016  Game of the Year  Uncharted 4: A Thief's End
#
#                     company  winner voted
# 215  Blizzard Entertainment       1  jury
# 216             id Software       0  jury
# 217                Playdead       0  jury
# 218   Respawn Entertainment       0  jury
# 219             Naughty Dog       0  jury

# %%
mask2016 = df['Year'] == 2016
 
df_2016 = pd.DataFrame(df[mask2016])
 
# print(df_new)
grouped2016  = df_2016.groupby("Game")
# sum and average the other information by game

result2016 = grouped2016.agg({"Game" : "first","Hours_watched": "sum", "Hours_streamed": "max", "Peak_channels": "max", "Streamers": "mean"})
print(result2016)
# Out:
#                                                             Game  \
# Game
# 60 Seconds!                                          60 Seconds!
# 7 Days to Die                                      7 Days to Die
# ABZ<U+00DB>                                          ABZ<U+00DB>
# APB Reloaded                                        APB Reloaded
# ARAYA                                                      ARAYA
# ...                                                          ...
# Z1: Battle Royale                              Z1: Battle Royale
# Zelda II: The Adventure of Link  Zelda II: The Adventure of Link
# Zero Escape: Zero Time Dilemma    Zero Escape: Zero Time Dilemma
# iRacing                                                  iRacing
# osu!                                                        osu!
#
#                                  Hours_watched  Hours_streamed  Peak_channels  \
# Game
# 60 Seconds!                            1151013            2065             30
# 7 Days to Die                          6639960          190266            950
# ABZ<U+00DB>                             338342            5738            116
# APB Reloaded                            277614           10747             37
# ARAYA                                   142823             437             12
# ...                                        ...             ...            ...
# Z1: Battle Royale                     87872183          370148            882
# Zelda II: The Adventure of Link         181560             747             12
# Zero Escape: Zero Time Dilemma          321911            3755             27
# iRacing                                 461402            8320             61
# osu!                                   6917396           71335            192
#
#                                     Streamers
# Game
# 60 Seconds!                        365.333333
# 7 Days to Die                     6969.333333
# ABZ<U+00DB>                       2587.000000
# APB Reloaded                      1073.000000
# ARAYA                              184.000000
# ...                                       ...
# Z1: Battle Royale                15932.500000
# Zelda II: The Adventure of Link    100.000000
# Zero Escape: Zero Time Dilemma     401.000000
# iRacing                            654.500000
# osu!                             12629.333333
#
# [620 rows x 5 columns]

# %%
mask2017 = df['Year'] == 2017
 
df_2017 = pd.DataFrame(df[mask2017])
 
# print(df_new)

grouped2017  = df_2017.groupby("Game")
# sum and average the other information by game

result2017  = grouped2017 .agg({"Game" : "first" ,"Hours_watched": "sum", "Hours_streamed": "max", "Peak_channels": "max", "Streamers": "mean"})
print(result2017)
# Out:
#                                                     Game  Hours_watched  \
# Game
# .hack//G.U. Last Recode          .hack//G.U. Last Recode         145350
# 60 Seconds!                                  60 Seconds!         623520
# 7 Days to Die                              7 Days to Die        8305182
# <U+014C>kami                                <U+014C>kami         181539
# A Hat in Time                              A Hat in Time         709295
# ...                                                  ...            ...
# Yu-Gi-Oh! Duel Links                Yu-Gi-Oh! Duel Links        1879042
# Z1: Battle Royale                      Z1: Battle Royale       89752462
# iRacing                                          iRacing         139492
# osu!                                                osu!        6680504
# theHunter: Call of the Wild  theHunter: Call of the Wild        1867184
#
#                              Hours_streamed  Peak_channels     Streamers
# Game
# .hack//G.U. Last Recode               35258            258   3174.000000
# 60 Seconds!                             679             10    242.666667
# 7 Days to Die                         94377            266   7016.916667
# <U+014C>kami                          19273            148   3305.000000
# A Hat in Time                         20147            182   2232.500000
# ...                                     ...            ...           ...
# Yu-Gi-Oh! Duel Links                  13456             52    877.750000
# Z1: Battle Royale                    482900           1184  28988.166667
# iRacing                               11507            131   1025.000000
# osu!                                  85603            237  16223.500000
# theHunter: Call of the Wild           11504             71   1219.285714
#
# [597 rows x 5 columns]

# %%
mask2018 = df['Year'] == 2018
 
df_2018 = pd.DataFrame(df[mask2018])
 
# print(df_new)

grouped2018  = df_2018.groupby("Game")
# sum and average the other information by game

result2018  = grouped2018.agg({"Game" : "first" ,"Hours_watched": "sum", "Hours_streamed": "max", "Peak_channels": "max", "Streamers": "mean"})
print(result2018)
# Out:
#                                                                                                 Game  \
# Game
# 60 Parsecs!                                                                              60 Parsecs!
# 60 Seconds!                                                                              60 Seconds!
# 7 Days to Die                                                                          7 Days to Die
# A Hat in Time                                                                          A Hat in Time
# A Way Out                                                                                  A Way Out
# ...                                                                                              ...
# Z1: Battle Royale                                                                  Z1: Battle Royale
# Zero Escape: Nine Hours, Nine Persons, Nine Doors  Zero Escape: Nine Hours, Nine Persons, Nine Doors
# iRacing                                                                                      iRacing
# osu!                                                                                            osu!
# theHunter: Call of the Wild                                              theHunter: Call of the Wild
#
#                                                    Hours_watched  \
# Game
# 60 Parsecs!                                               529688
# 60 Seconds!                                               222209
# 7 Days to Die                                            6897693
# A Hat in Time                                             286598
# A Way Out                                                6505470
# ...                                                          ...
# Z1: Battle Royale                                       13886280
# Zero Escape: Nine Hours, Nine Persons, Nine Doors         197213
# iRacing                                                  1483730
# osu!                                                     9977990
# theHunter: Call of the Wild                               342667
#
#                                                    Hours_streamed  \
# Game
# 60 Parsecs!                                                  1867
# 60 Seconds!                                                   871
# 7 Days to Die                                               80431
# A Hat in Time                                               14520
# A Way Out                                                   89705
# ...                                                           ...
# Z1: Battle Royale                                          119368
# Zero Escape: Nine Hours, Nine Persons, Nine Doors             661
# iRacing                                                     21577
# osu!                                                       134145
# theHunter: Call of the Wild                                  8633
#
#                                                    Peak_channels     Streamers
# Game
# 60 Parsecs!                                                   27    606.000000
# 60 Seconds!                                                    8    414.000000
# 7 Days to Die                                                293   5587.000000
# A Hat in Time                                                182   3065.000000
# A Way Out                                                   1587  17175.000000
# ...                                                          ...           ...
# Z1: Battle Royale                                            675  11250.250000
# Zero Escape: Nine Hours, Nine Persons, Nine Doors              7     62.000000
# iRacing                                                      217   1549.833333
# osu!                                                         333  25226.500000
# theHunter: Call of the Wild                                   28   1851.000000
#
# [586 rows x 5 columns]

# %%
result2016.reset_index(drop=True, inplace=True)
# Rename the 'nominee' column in goty_df to 'Game' to match with results_df
goty_2016 = goty_2016.rename(columns={'nominee': 'Game'})

# Merge the dataframes based on the 'Game' column
merged_df = pd.merge(goty_2016, result2016, on='Game')

# Select the 'Game', 'winner', and 'category' columns
selected_df = merged_df[['Game', 'winner', 'category','Hours_watched', 'Hours_streamed', 'Peak_channels']]
encoded_df = selected_df.drop_duplicates(subset='Game', keep='first')
#shows all categories 
encoded_df
#only shows goty 
goty_df = encoded_df[encoded_df['category'] == 'Game of the Year']
# Out:
#                                 Game  winner                   category  \
# 0                          Overwatch       1           Game of the Year
# 6                        Titanfall 2       0           Game of the Year
# 10        Uncharted 4: A Thief's End       0           Game of the Year
# 15                     Battlefield 1       0      Developer of the Year
# 19                         Firewatch       0             Best Narrative
# 22                         Mafia III       0             Best Narrative
# 23               Hyper Light Drifter       0      Best Independent Game
# 25                    Stardew Valley       0      Best Independent Game
# 26                       The Witness       0      Best Independent Game
# 27                      Clash Royale       0  Best Mobile/Handheld Game
# 28        Monster Hunter Generations       0  Best Mobile/Handheld Game
# 29                    Gears of War 4       0           Best Action Game
# 31                      Dishonored 2       1      Best Action/Adventure
# 32                   Ratchet & Clank       0      Best Action/Adventure
# 34                    Dark Souls III       0     Best Role Playing Game
# 35          Deus Ex: Mankind Divided       0     Best Role Playing Game
# 36                  Street Fighter V       1         Best Fighting Game
# 38          The King of Fighters XIV       0         Best Fighting Game
# 39              Total War: Warhammer       0         Best Strategy Game
# 40                            XCOM 2       0         Best Strategy Game
# 41             Dragon Quest Builders       0           Best Family Game
# 42                   Forza Horizon 3       1    Best Sports/Racing Game
# 43                           FIFA 17       0    Best Sports/Racing Game
# 44                   MLB The Show 16       0    Best Sports/Racing Game
# 45                          NBA 2K17       0    Best Sports/Racing Game
# 46         Pro Evolution Soccer 2017       0    Best Sports/Racing Game
# 47    Tom Clancy's Rainbow Six Siege       0           Best Multiplayer
# 48  Counter-Strike: Global Offensive       0   ESports Game of the Year
# 49                            Dota 2       0   ESports Game of the Year
# 50                 League of Legends       0   ESports Game of the Year
#
#     Hours_watched  Hours_streamed  Peak_channels
# 0       178952454         1141859           9741
# 6         3217479           51299            379
# 10        6336406          140927            739
# 15       20187602          396583           1548
# 19        1569072           28712            700
# 22        2969888          134571           1429
# 23         256429           11517            120
# 25        9902673          137735            375
# 26        1209558           16728            193
# 27       13483949           28640             86
# 28        1104972           13415             92
# 29        4570995          158079           1239
# 31        2540883           49624            389
# 32         780678           10301            117
# 34       43746685          749702           3238
# 35        2635172           28711            723
# 36       34646634           68678            760
# 38         706275            6925             85
# 39        4697524           28006            418
# 40        7668219          101051            782
# 41         518236           18307            109
# 42        1390974           50930            430
# 43       28660792          213882           1142
# 44        1410572            9580             72
# 45       10523416          198380           1778
# 46         161557           10351             78
# 47       32430212          319737            929
# 48      526391918          830105           2197
# 49      496585969          433397           1100
# 50     1035469850         1362044           2945

# %%
# folder = "D:\\desktop\\all coding ive done\\"
# file = "result2016.xlsx"
# # create an ExcelWriter object
# writer = pd.ExcelWriter(folder + file, engine="xlsxwriter")
# # write the dataframe to the excel file
# goty_df.to_excel(writer, index=False)
# # save and close the writer
# writer.save()

# %%
#this returns only one winner on the category goty 
# goty_winners = set(goty_df.loc[goty_df['winner'] == 1, 'Game'])

# # Create a new column 'goty' in the 'result2016' dataframe
# # If the game is a Game of the Year winner, set 'goty' to 1, otherwise set it to 0
# result2016['goty'] = result2016['Game'].apply(lambda x: 1 if x in goty_winners else 0)
# Out:
#                           Game  winner          category  Hours_watched  \
# 0                    Overwatch       1  Game of the Year      178952454
# 6                  Titanfall 2       0  Game of the Year        3217479
# 10  Uncharted 4: A Thief's End       0  Game of the Year        6336406
#
#     Hours_streamed  Peak_channels
# 0          1141859           9741
# 6            51299            379
# 10          140927            739

# %%
# folder = "D:\\desktop\\all coding ive done\\"
# file = "result2016.xlsx"
# # create an ExcelWriter object
# writer = pd.ExcelWriter(folder + file, engine="xlsxwriter")
# # write the dataframe to the excel file
# result2016.to_excel(writer, index=False)
# # save and close the writer
# writer.save()

# %%
encoded_df
# Out:
#                                 Game  winner                   category  \
# 0                          Overwatch       1           Game of the Year
# 6                        Titanfall 2       0           Game of the Year
# 10        Uncharted 4: A Thief's End       0           Game of the Year
# 15                     Battlefield 1       0      Developer of the Year
# 19                         Firewatch       0             Best Narrative
# 22                         Mafia III       0             Best Narrative
# 23               Hyper Light Drifter       0      Best Independent Game
# 25                    Stardew Valley       0      Best Independent Game
# 26                       The Witness       0      Best Independent Game
# 27                      Clash Royale       0  Best Mobile/Handheld Game
# 28        Monster Hunter Generations       0  Best Mobile/Handheld Game
# 29                    Gears of War 4       0           Best Action Game
# 31                      Dishonored 2       1      Best Action/Adventure
# 32                   Ratchet & Clank       0      Best Action/Adventure
# 34                    Dark Souls III       0     Best Role Playing Game
# 35          Deus Ex: Mankind Divided       0     Best Role Playing Game
# 36                  Street Fighter V       1         Best Fighting Game
# 38          The King of Fighters XIV       0         Best Fighting Game
# 39              Total War: Warhammer       0         Best Strategy Game
# 40                            XCOM 2       0         Best Strategy Game
# 41             Dragon Quest Builders       0           Best Family Game
# 42                   Forza Horizon 3       1    Best Sports/Racing Game
# 43                           FIFA 17       0    Best Sports/Racing Game
# 44                   MLB The Show 16       0    Best Sports/Racing Game
# 45                          NBA 2K17       0    Best Sports/Racing Game
# 46         Pro Evolution Soccer 2017       0    Best Sports/Racing Game
# 47    Tom Clancy's Rainbow Six Siege       0           Best Multiplayer
# 48  Counter-Strike: Global Offensive       0   ESports Game of the Year
# 49                            Dota 2       0   ESports Game of the Year
# 50                 League of Legends       0   ESports Game of the Year
#
#     Hours_watched  Hours_streamed  Peak_channels
# 0       178952454         1141859           9741
# 6         3217479           51299            379
# 10        6336406          140927            739
# 15       20187602          396583           1548
# 19        1569072           28712            700
# 22        2969888          134571           1429
# 23         256429           11517            120
# 25        9902673          137735            375
# 26        1209558           16728            193
# 27       13483949           28640             86
# 28        1104972           13415             92
# 29        4570995          158079           1239
# 31        2540883           49624            389
# 32         780678           10301            117
# 34       43746685          749702           3238
# 35        2635172           28711            723
# 36       34646634           68678            760
# 38         706275            6925             85
# 39        4697524           28006            418
# 40        7668219          101051            782
# 41         518236           18307            109
# 42        1390974           50930            430
# 43       28660792          213882           1142
# 44        1410572            9580             72
# 45       10523416          198380           1778
# 46         161557           10351             78
# 47       32430212          319737            929
# 48      526391918          830105           2197
# 49      496585969          433397           1100
# 50     1035469850         1362044           2945

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
feature_cols = ['Hours_watched','Hours_streamed','Peak_channels']

# %%
X = encoded_df[feature_cols]

# %%
y=encoded_df['winner']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=10)
#print(y_test)
print(X_test)
# Out:
#     Hours_watched  Hours_streamed  Peak_channels
# 41         518236           18307            109
# 25        9902673          137735            375
# 22        2969888          134571           1429
# 10        6336406          140927            739
# 15       20187602          396583           1548
# 42        1390974           50930            430
# 32         780678           10301            117
# 48      526391918          830105           2197
# 31        2540883           49624            389
# 6         3217479           51299            379
# 40        7668219          101051            782
# 34       43746685          749702           3238
# 39        4697524           28006            418
# 23         256429           11517            120
# 29        4570995          158079           1239
# 44        1410572            9580             72
# 45       10523416          198380           1778
# 49      496585969          433397           1100

# %%
my_logreg = LogisticRegression()
my_logreg.fit(X_train,y_train)
y_predict_logreg=my_logreg.predict(X_test)
logregaccuracy=accuracy_score(y_test,y_predict_logreg)
print(round(logregaccuracy, 2))
# Out:
# 0.22

# %%
k = 7
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train,y_train)
y_predict_knn = knn.predict(X_test)
knnaccuracy = accuracy_score(y_test, y_predict_knn)

print(round(knnaccuracy,2))
# Out:
# 0.89

# %%
#create decisiontree
my_decisiontree = DecisionTreeClassifier(random_state=5)
my_decisiontree.fit(X_train, y_train)
y_predict_mdt=my_decisiontree.predict(X_test)
mdtaccuracy= accuracy_score(y_test,y_predict_mdt)
print(round(mdtaccuracy,2))
# Out:
# 0.72
